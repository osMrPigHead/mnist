# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from main import Model

# %%
model = Model.load("model.npz")

# %%
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(model.layer_w[0][:,i].reshape((28, 28)), norm=colors.CenteredNorm(), cmap="bwr")

# %%
for i in range(10):
    plt.subplot(3, 4, i + 1)
    plt.imshow(model.layer_w[1][:,i].reshape((4, 4)), norm=colors.CenteredNorm(), cmap="bwr")
